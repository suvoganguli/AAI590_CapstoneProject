# %% [markdown]
# # 05b: CNN-LSTM Model Design and Training
#
# This notebook provides a comprehensive workflow for designing, training, and evaluating a hybrid CNN-LSTM model for ICU mortality prediction using preprocessed time series and static patient data.

# %% [markdown]
# #### 1. Imports and Configuration
#
# Import all necessary libraries for deep learning model development, training, and evaluation. This includes TensorFlow/Keras for model building, scikit-learn for metrics and cross-validation, and other utilities for data handling and visualization.

# %%
# Imports and Configuration

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from keras_tuner import HyperParameters
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Concatenate
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import pickle
import matplotlib.pyplot as plt
import pandas as pd
import os
from sklearn.metrics import classification_report, roc_curve, auc, confusion_matrix
import seaborn as sns
from sklearn.model_selection import StratifiedKFold


np.random.seed(42)

tf.random.set_seed(42)

# %% [markdown]
# ### 2. Model Architecture - CNN-LSTM Hybrid
#
# Hybrid deep learning model architecture combining CNN and LSTM layers. This model leverages both temporal patterns in time series data and static patient features for ICU mortality prediction.
#
# **Key Design Choices:**
# - **CNN Layers:** Extract local temporal features from the time series input, capturing short-term dependencies and patterns.
# - **LSTM Layer:** Captures long-term dependencies and trends in the sequential data, which are important for patient outcome prediction.
# - **Static Input:** Patient static features  are included as a separate input and concatenated with the sequence features after feature extraction.
# - **Dense Layers:** Combine the extracted sequence and static features to learn complex interactions.
# - **Regularization:** Dropout and L2 regularization are used to prevent overfitting and improve generalization.
# - **Output Layer:** A single neuron with sigmoid activation for binary classification (mortality prediction).
#
# **Inputs:**
# - Time series features: shape = [batch, timesteps, features]
# - Static features: shape = [batch, static_features]
#
# **Output:**
# - Binary prediction: 0 = survived, 1 = deceased

# %%
def build_cnn_lstm_model(time_series_input_shape, static_input_shape):
    """Builds and compiles the CNN-LSTM model."""
    # Time-series branch
    time_series_input = Input(shape=time_series_input_shape, name='time_series_input')

    x = Conv1D(64, 3, activation='relu', padding='same', kernel_regularizer=l2(1e-4))(time_series_input)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(0.3)(x)

    x = Conv1D(128, 3, activation='relu', padding='same', kernel_regularizer=l2(1e-4))(x)
    # Reduce pooling impact for short sequences
    x = MaxPooling1D(pool_size=1)(x)
    x = Dropout(0.3)(x)

    x = LSTM(64, return_sequences=False, kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.3)(x)

    # Static branch
    static_input = Input(shape=static_input_shape, name='static_input')
    y = Dense(32, activation='relu')(static_input)
    y = Dense(16, activation='relu')(y)

    # Merge branches
    combined = Concatenate()([x, y])

    z = Dense(64, activation='relu')(combined)
    z = Dropout(0.3)(z)
    z = Dense(32, activation='relu')(z)

    output = Dense(1, activation='sigmoid', name='output')(z)

    model = Model(inputs=[time_series_input, static_input], outputs=output)

    # Compile the model
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['AUC', 'Precision', 'Recall'])

    return model

# %%
class CNN_LSTM_Model:
    def __init__(self, time_series_input_shape, static_input_shape):
        """Initializes the CNN-LSTM model."""
        self.model = build_cnn_lstm_model(time_series_input_shape, static_input_shape)

    def compile_model(self, learning_rate=1e-3):
        """Compiles the model with specified parameters."""
        self.model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
            loss='binary_crossentropy',
            metrics=[
                'accuracy',
                tf.keras.metrics.AUC(name='AUC'),
                tf.keras.metrics.Precision(name='Precision'),
                tf.keras.metrics.Recall(name='Recall')
            ]
        )
        print("Model compiled successfully.")

    def train_model(self, X_train, static_train, y_train, X_val, static_val, y_val, epochs=100, batch_size=32, model_save_path='best_model.keras'):
        """Trains the model with early stopping and model checkpointing."""
        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=10,
            restore_best_weights=True
        )

        model_checkpoint = ModelCheckpoint(
            filepath=model_save_path,
            monitor='val_loss',
            save_best_only=True,
            save_weights_only=False,
            mode='min',
            verbose=1
        )

        print("Training model...")
        history = self.model.fit(
            x=[X_train, static_train],
            y=y_train,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=([X_val, static_val], y_val),
            callbacks=[early_stopping, model_checkpoint],
            verbose=1
        )
        print("Model training finished.")
        return history

    def evaluate_model(self, X_test, static_test, y_test):
        """Evaluates the model on the test data."""
        print("Evaluating model...")
        loss, accuracy, auc, precision, recall = self.model.evaluate(
            x=[X_test, static_test],
            y=y_test,
            verbose=0
        )
        print("Model evaluation finished.")
        return loss, accuracy, auc, precision, recall

    def predict(self, X_test, static_test):
        """Generates predictions for the test data."""
        print("Generating predictions...")
        predictions = self.model.predict(x=[X_test, static_test], verbose=0)
        print("Prediction generation finished.")
        return predictions

# %% [markdown]
# ### 3. Data Loading Method
#
# Define a function to load ICU time series and static patient data from .npz files. This step prepares the training, validation, and test sets for model development and evaluation.

# %%
def load_icu_data(data_path):
    """Loads ICU data from a specified .npz file.

    Args:
        data_path (str): The path to the .npz data file.

    Returns:
        tuple: A tuple containing the loaded data arrays:
               (X_train, X_val, X_test, static_train, static_val, static_test, y_train, y_val, y_test)
    """
    data = np.load(data_path, allow_pickle=True)

    # Time-series inputs
    X_train = data['X_train']
    X_val = data['X_val']
    X_test = data['X_test']

    # Static inputs
    static_train = data['static_train']
    static_val = data['static_val']
    static_test = data['static_test']

    # Labels
    y_train = data['y_train']
    y_val = data['y_val']
    y_test = data['y_test']

    return X_train, X_val, X_test, static_train, static_val, static_test, y_train, y_val, y_test

# %% [markdown]
# ### 4. Dataset Selection
#
# Identify and select the appropriate temporal dataset for model training and evaluation. This step ensures the model is trained on data with the desired time window (e.g., 6, 12, 36, or 48 hours).

# %%
def run_experiment(data_path):
    """Runs a complete CNN-LSTM experiment on data from the given path."""

    # Load the data
    X_train, X_val, X_test, static_train, static_val, static_test, y_train, y_val, y_test = load_icu_data(data_path)
    print(f"Data loaded from: {data_path}")
    print(f"X_train shape: {X_train.shape}, static_train shape: {static_train.shape}, y_train shape: {y_train.shape}")

    # Determine input shapes
    time_series_input_shape = (X_train.shape[1], X_train.shape[2])
    static_input_shape = (static_train.shape[1],)
    print(f"Time series input shape: {time_series_input_shape}, Static input shape: {static_input_shape}")

    # Instantiate the model
    cnn_lstm_model = CNN_LSTM_Model(time_series_input_shape, static_input_shape)
    print("CNN_LSTM_Model instantiated.")

    # Compile the model
    cnn_lstm_model.compile_model()


    # Train the model
    epochs = 50  # Set a fixed number of epochs for each experiment
    batch_size = 32
    print(f"Starting model training for {epochs} epochs with batch size {batch_size}...")
    history = cnn_lstm_model.train_model(
        X_train, static_train, y_train,
        X_val, static_val, y_val,
        epochs=epochs,
        batch_size=batch_size,

    )
    print("Model training completed.")


    # Evaluate the model on the test data
    print("Evaluating model on test data...")
    loss, accuracy, auc, precision, recall = cnn_lstm_model.evaluate_model(
        X_test, static_test, y_test
    )
    print("Model evaluation completed.")

    # Generate predictions and classification report
    y_pred_prob = cnn_lstm_model.predict(X_test, static_test)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)

    print("\n--- Classification Report ---")
    print(classification_report(y_test, y_pred_binary, target_names=['No Mortality', 'Mortality']))


    # Return evaluation metrics
    return {
        'loss': loss,
        'accuracy': accuracy,
        'auc': auc,
        'precision': precision,
        'recall': recall
    }

# %%
dataset_paths = [
    '../data/processed/cnn_lstm_48hour_data.npz',
    '../data/processed/cnn_lstm_6hour_data.npz',
    '../data/processed/cnn_lstm_12hour_data.npz',
    '../data/processed/cnn_lstm_36hour_data.npz'
]

print("Dataset paths list created:")
for path in dataset_paths:
    print(path)
# Out:
# Dataset paths list created:
# /content/sample_data/cnn_lstm_48hour_data.npz
# /content/sample_data/cnn_lstm_6hour_data.npz
# /content/sample_data/cnn_lstm_12hour_data.npz
# /content/sample_data/cnn_lstm_36hour_data.npz

# %% [markdown]
# ### 5. Experiment Loop Across Datasets
#
# Define the list of dataset paths and run the CNN-LSTM experiment for each dataset. Collect evaluation metrics for comparison across different temporal windows.

# %%
# List to store results for each dataset
all_results = []

# Iterate through the dataset paths and run experiments
for dataset_path in dataset_paths:
    print(f"\n--- Running experiment for {dataset_path} ---")
    results = run_experiment(dataset_path)
    results['dataset'] = dataset_path  
    all_results.append(results)

print("\n--- All experiments finished ---")
# Out:
# --- Running experiment for /content/sample_data/cnn_lstm_48hour_data.npz ---
# Data loaded from: /content/sample_data/cnn_lstm_48hour_data.npz
# X_train shape: (4406, 48, 28), static_train shape: (4406, 7), y_train shape: (4406,)
# Time series input shape: (48, 28), Static input shape: (7,)
# CNN_LSTM_Model instantiated.
# Model compiled successfully.
# Starting model training for 50 epochs with batch size 32...
# Training model...
# Epoch 1/50
# 135/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.7126 - Precision: 0.6603 - Recall: 0.6273 - accuracy: 0.6546 - loss: 0.6440
# Epoch 1: val_loss improved from inf to 0.64264, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - AUC: 0.7147 - Precision: 0.6616 - Recall: 0.6301 - accuracy: 0.6563 - loss: 0.6423 - val_AUC: 0.7693 - val_Precision: 0.2545 - val_Recall: 0.7978 - val_accuracy: 0.6469 - val_loss: 0.6426
# Epoch 2/50
# 134/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8335 - Precision: 0.7414 - Recall: 0.8474 - accuracy: 0.7754 - loss: 0.5178
# Epoch 2: val_loss improved from 0.64264 to 0.60226, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.8343 - Precision: 0.7420 - Recall: 0.8477 - accuracy: 0.7760 - loss: 0.5167 - val_AUC: 0.7806 - val_Precision: 0.2783 - val_Recall: 0.7191 - val_accuracy: 0.7016 - val_loss: 0.6023
# Epoch 3/50
# 134/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8784 - Precision: 0.7761 - Recall: 0.8811 - accuracy: 0.8131 - loss: 0.4513
# Epoch 3: val_loss improved from 0.60226 to 0.59808, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.8788 - Precision: 0.7764 - Recall: 0.8808 - accuracy: 0.8132 - loss: 0.4507 - val_AUC: 0.7782 - val_Precision: 0.2699 - val_Recall: 0.6854 - val_accuracy: 0.6984 - val_loss: 0.5981
# Epoch 4/50
# 137/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.8898 - Precision: 0.7933 - Recall: 0.8863 - accuracy: 0.8274 - loss: 0.4295
# Epoch 4: val_loss improved from 0.59808 to 0.57994, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.8900 - Precision: 0.7934 - Recall: 0.8863 - accuracy: 0.8275 - loss: 0.4292 - val_AUC: 0.7670 - val_Precision: 0.2973 - val_Recall: 0.6180 - val_accuracy: 0.7437 - val_loss: 0.5799
# Epoch 5/50
# 137/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9147 - Precision: 0.8205 - Recall: 0.8966 - accuracy: 0.8500 - loss: 0.3832
# Epoch 5: val_loss improved from 0.57994 to 0.56643, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - AUC: 0.9148 - Precision: 0.8206 - Recall: 0.8965 - accuracy: 0.8500 - loss: 0.3829 - val_AUC: 0.7751 - val_Precision: 0.3086 - val_Recall: 0.5618 - val_accuracy: 0.7641 - val_loss: 0.5664
# Epoch 6/50
# 134/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9308 - Precision: 0.8455 - Recall: 0.9042 - accuracy: 0.8692 - loss: 0.3453
# Epoch 6: val_loss did not improve from 0.56643
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.9311 - Precision: 0.8458 - Recall: 0.9043 - accuracy: 0.8695 - loss: 0.3447 - val_AUC: 0.7654 - val_Precision: 0.3059 - val_Recall: 0.5843 - val_accuracy: 0.7578 - val_loss: 0.6070
# Epoch 7/50
# 136/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9474 - Precision: 0.8673 - Recall: 0.9250 - accuracy: 0.8916 - loss: 0.3089
# Epoch 7: val_loss did not improve from 0.56643
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.9474 - Precision: 0.8673 - Recall: 0.9250 - accuracy: 0.8916 - loss: 0.3087 - val_AUC: 0.7600 - val_Precision: 0.2945 - val_Recall: 0.5393 - val_accuracy: 0.7563 - val_loss: 0.5972
# Epoch 8/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9501 - Precision: 0.8636 - Recall: 0.9248 - accuracy: 0.8891 - loss: 0.3048
# Epoch 8: val_loss did not improve from 0.56643
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.9502 - Precision: 0.8637 - Recall: 0.9248 - accuracy: 0.8892 - loss: 0.3047 - val_AUC: 0.7681 - val_Precision: 0.3224 - val_Recall: 0.5506 - val_accuracy: 0.7766 - val_loss: 0.5941
# Epoch 9/50
# 135/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9626 - Precision: 0.8862 - Recall: 0.9245 - accuracy: 0.9027 - loss: 0.2677
# Epoch 9: val_loss improved from 0.56643 to 0.49845, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.9626 - Precision: 0.8864 - Recall: 0.9246 - accuracy: 0.9029 - loss: 0.2674 - val_AUC: 0.7745 - val_Precision: 0.3727 - val_Recall: 0.4607 - val_accuracy: 0.8172 - val_loss: 0.4984
# Epoch 10/50
# 137/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9688 - Precision: 0.9175 - Recall: 0.9317 - accuracy: 0.9239 - loss: 0.2430
# Epoch 10: val_loss did not improve from 0.49845
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.9688 - Precision: 0.9174 - Recall: 0.9318 - accuracy: 0.9238 - loss: 0.2429 - val_AUC: 0.7545 - val_Precision: 0.3435 - val_Recall: 0.5056 - val_accuracy: 0.7969 - val_loss: 0.5948
# Epoch 11/50
# 137/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9729 - Precision: 0.9111 - Recall: 0.9375 - accuracy: 0.9229 - loss: 0.2299
# Epoch 11: val_loss did not improve from 0.49845
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.9729 - Precision: 0.9111 - Recall: 0.9375 - accuracy: 0.9229 - loss: 0.2299 - val_AUC: 0.7676 - val_Precision: 0.3245 - val_Recall: 0.5506 - val_accuracy: 0.7781 - val_loss: 0.5980
# Epoch 12/50
# 135/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9725 - Precision: 0.9115 - Recall: 0.9359 - accuracy: 0.9224 - loss: 0.2302
# Epoch 12: val_loss did not improve from 0.49845
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.9726 - Precision: 0.9115 - Recall: 0.9359 - accuracy: 0.9224 - loss: 0.2300 - val_AUC: 0.7562 - val_Precision: 0.3356 - val_Recall: 0.5506 - val_accuracy: 0.7859 - val_loss: 0.6421
# Epoch 13/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9797 - Precision: 0.9290 - Recall: 0.9472 - accuracy: 0.9374 - loss: 0.2016
# Epoch 13: val_loss did not improve from 0.49845
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.9798 - Precision: 0.9291 - Recall: 0.9473 - accuracy: 0.9375 - loss: 0.2013 - val_AUC: 0.7131 - val_Precision: 0.3304 - val_Recall: 0.4270 - val_accuracy: 0.8000 - val_loss: 0.6720
# Epoch 14/50
# 136/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9814 - Precision: 0.9338 - Recall: 0.9467 - accuracy: 0.9397 - loss: 0.1956
# Epoch 14: val_loss did not improve from 0.49845
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.9814 - Precision: 0.9337 - Recall: 0.9467 - accuracy: 0.9396 - loss: 0.1955 - val_AUC: 0.7378 - val_Precision: 0.3509 - val_Recall: 0.4494 - val_accuracy: 0.8078 - val_loss: 0.5883
# Epoch 15/50
# 134/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9844 - Precision: 0.9379 - Recall: 0.9533 - accuracy: 0.9450 - loss: 0.1826
# Epoch 15: val_loss did not improve from 0.49845
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.9844 - Precision: 0.9379 - Recall: 0.9531 - accuracy: 0.9449 - loss: 0.1824 - val_AUC: 0.7143 - val_Precision: 0.3333 - val_Recall: 0.4607 - val_accuracy: 0.7969 - val_loss: 0.7384
# Epoch 16/50
# 137/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9854 - Precision: 0.9330 - Recall: 0.9585 - accuracy: 0.9448 - loss: 0.1758
# Epoch 16: val_loss did not improve from 0.49845
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.9854 - Precision: 0.9331 - Recall: 0.9584 - accuracy: 0.9448 - loss: 0.1758 - val_AUC: 0.7436 - val_Precision: 0.3267 - val_Recall: 0.5506 - val_accuracy: 0.7797 - val_loss: 0.7930
# Epoch 17/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9825 - Precision: 0.9291 - Recall: 0.9429 - accuracy: 0.9352 - loss: 0.1924
# Epoch 17: val_loss did not improve from 0.49845
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.9826 - Precision: 0.9292 - Recall: 0.9429 - accuracy: 0.9353 - loss: 0.1922 - val_AUC: 0.6977 - val_Precision: 0.3103 - val_Recall: 0.4045 - val_accuracy: 0.7922 - val_loss: 0.6927
# Epoch 18/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9912 - Precision: 0.9514 - Recall: 0.9590 - accuracy: 0.9550 - loss: 0.1463
# Epoch 18: val_loss did not improve from 0.49845
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9912 - Precision: 0.9513 - Recall: 0.9588 - accuracy: 0.9549 - loss: 0.1467 - val_AUC: 0.7004 - val_Precision: 0.2847 - val_Recall: 0.4607 - val_accuracy: 0.7641 - val_loss: 0.7769
# Epoch 19/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9887 - Precision: 0.9434 - Recall: 0.9617 - accuracy: 0.9519 - loss: 0.1598
# Epoch 19: val_loss did not improve from 0.49845
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.9887 - Precision: 0.9434 - Recall: 0.9617 - accuracy: 0.9519 - loss: 0.1598 - val_AUC: 0.7224 - val_Precision: 0.3256 - val_Recall: 0.4719 - val_accuracy: 0.7906 - val_loss: 0.7345
# Model training finished.
# Model training completed.
# Evaluating model on test data...
# Evaluating model...
# Model evaluation finished.
# Model evaluation completed.
# Generating predictions...
# Prediction generation finished.
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
# No Mortality       0.90      0.90      0.90       689
#    Mortality       0.38      0.38      0.38       111
#
#     accuracy                           0.83       800
#    macro avg       0.64      0.64      0.64       800
# weighted avg       0.83      0.83      0.83       800
#
#
# --- Running experiment for /content/sample_data/cnn_lstm_6hour_data.npz ---
# Data loaded from: /content/sample_data/cnn_lstm_6hour_data.npz
# X_train shape: (4406, 6, 28), static_train shape: (4406, 7), y_train shape: (4406,)
# Time series input shape: (6, 28), Static input shape: (7,)
# CNN_LSTM_Model instantiated.
# Model compiled successfully.
# Starting model training for 50 epochs with batch size 32...
# Training model...
# Epoch 1/50
# 134/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.6739 - Precision: 0.6319 - Recall: 0.4990 - accuracy: 0.6070 - loss: 0.6712
# Epoch 1: val_loss improved from inf to 0.61961, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - AUC: 0.6765 - Precision: 0.6335 - Recall: 0.5046 - accuracy: 0.6093 - loss: 0.6694 - val_AUC: 0.7365 - val_Precision: 0.2470 - val_Recall: 0.6966 - val_accuracy: 0.6625 - val_loss: 0.6196
# Epoch 2/50
# 134/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8004 - Precision: 0.7129 - Recall: 0.8190 - accuracy: 0.7440 - loss: 0.5625
# Epoch 2: val_loss improved from 0.61961 to 0.58051, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8009 - Precision: 0.7135 - Recall: 0.8191 - accuracy: 0.7446 - loss: 0.5618 - val_AUC: 0.7357 - val_Precision: 0.2308 - val_Recall: 0.6067 - val_accuracy: 0.6641 - val_loss: 0.5805
# Epoch 3/50
# 134/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8324 - Precision: 0.7302 - Recall: 0.8296 - accuracy: 0.7612 - loss: 0.5211
# Epoch 3: val_loss improved from 0.58051 to 0.57948, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8328 - Precision: 0.7307 - Recall: 0.8300 - accuracy: 0.7617 - loss: 0.5206 - val_AUC: 0.7463 - val_Precision: 0.2479 - val_Recall: 0.6629 - val_accuracy: 0.6734 - val_loss: 0.5795
# Epoch 4/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8613 - Precision: 0.7496 - Recall: 0.8526 - accuracy: 0.7833 - loss: 0.4851
# Epoch 4: val_loss improved from 0.57948 to 0.57583, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8617 - Precision: 0.7505 - Recall: 0.8525 - accuracy: 0.7839 - loss: 0.4845 - val_AUC: 0.7293 - val_Precision: 0.2488 - val_Recall: 0.5955 - val_accuracy: 0.6938 - val_loss: 0.5758
# Epoch 5/50
# 137/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8791 - Precision: 0.7762 - Recall: 0.8546 - accuracy: 0.8038 - loss: 0.4548
# Epoch 5: val_loss did not improve from 0.57583
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8792 - Precision: 0.7764 - Recall: 0.8546 - accuracy: 0.8039 - loss: 0.4546 - val_AUC: 0.7138 - val_Precision: 0.2454 - val_Recall: 0.5955 - val_accuracy: 0.6891 - val_loss: 0.6205
# Epoch 6/50
# 134/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8939 - Precision: 0.7957 - Recall: 0.8606 - accuracy: 0.8196 - loss: 0.4288
# Epoch 6: val_loss improved from 0.57583 to 0.54628, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.8941 - Precision: 0.7961 - Recall: 0.8606 - accuracy: 0.8198 - loss: 0.4284 - val_AUC: 0.7256 - val_Precision: 0.2620 - val_Recall: 0.5506 - val_accuracy: 0.7219 - val_loss: 0.5463
# Epoch 7/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9106 - Precision: 0.8016 - Recall: 0.8728 - accuracy: 0.8280 - loss: 0.3988
# Epoch 7: val_loss did not improve from 0.54628
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9107 - Precision: 0.8021 - Recall: 0.8724 - accuracy: 0.8283 - loss: 0.3985 - val_AUC: 0.7180 - val_Precision: 0.2457 - val_Recall: 0.4831 - val_accuracy: 0.7219 - val_loss: 0.5679
# Epoch 8/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9190 - Precision: 0.8182 - Recall: 0.8831 - accuracy: 0.8431 - loss: 0.3804
# Epoch 8: val_loss improved from 0.54628 to 0.54458, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9190 - Precision: 0.8184 - Recall: 0.8825 - accuracy: 0.8431 - loss: 0.3803 - val_AUC: 0.7217 - val_Precision: 0.2761 - val_Recall: 0.5056 - val_accuracy: 0.7469 - val_loss: 0.5446
# Epoch 9/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9259 - Precision: 0.8301 - Recall: 0.8811 - accuracy: 0.8499 - loss: 0.3671
# Epoch 9: val_loss improved from 0.54458 to 0.54190, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9261 - Precision: 0.8308 - Recall: 0.8809 - accuracy: 0.8503 - loss: 0.3666 - val_AUC: 0.7239 - val_Precision: 0.3034 - val_Recall: 0.4944 - val_accuracy: 0.7719 - val_loss: 0.5419
# Epoch 10/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9312 - Precision: 0.8445 - Recall: 0.8826 - accuracy: 0.8597 - loss: 0.3542
# Epoch 10: val_loss did not improve from 0.54190
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9315 - Precision: 0.8449 - Recall: 0.8825 - accuracy: 0.8599 - loss: 0.3535 - val_AUC: 0.7241 - val_Precision: 0.2710 - val_Recall: 0.4719 - val_accuracy: 0.7500 - val_loss: 0.5962
# Epoch 11/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9451 - Precision: 0.8716 - Recall: 0.8776 - accuracy: 0.8739 - loss: 0.3213
# Epoch 11: val_loss did not improve from 0.54190
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9452 - Precision: 0.8716 - Recall: 0.8776 - accuracy: 0.8739 - loss: 0.3213 - val_AUC: 0.7139 - val_Precision: 0.2625 - val_Recall: 0.4719 - val_accuracy: 0.7422 - val_loss: 0.6156
# Epoch 12/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9507 - Precision: 0.8766 - Recall: 0.9013 - accuracy: 0.8870 - loss: 0.3053
# Epoch 12: val_loss did not improve from 0.54190
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9507 - Precision: 0.8765 - Recall: 0.9009 - accuracy: 0.8868 - loss: 0.3053 - val_AUC: 0.7097 - val_Precision: 0.2711 - val_Recall: 0.5056 - val_accuracy: 0.7422 - val_loss: 0.6563
# Epoch 13/50
# 137/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9484 - Precision: 0.8583 - Recall: 0.9031 - accuracy: 0.8768 - loss: 0.3140
# Epoch 13: val_loss did not improve from 0.54190
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9484 - Precision: 0.8585 - Recall: 0.9030 - accuracy: 0.8768 - loss: 0.3138 - val_AUC: 0.7062 - val_Precision: 0.2868 - val_Recall: 0.4382 - val_accuracy: 0.7703 - val_loss: 0.6095
# Epoch 14/50
# 136/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9549 - Precision: 0.8817 - Recall: 0.9087 - accuracy: 0.8932 - loss: 0.2941
# Epoch 14: val_loss did not improve from 0.54190
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9550 - Precision: 0.8817 - Recall: 0.9086 - accuracy: 0.8932 - loss: 0.2940 - val_AUC: 0.7122 - val_Precision: 0.2903 - val_Recall: 0.4045 - val_accuracy: 0.7797 - val_loss: 0.5987
# Epoch 15/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9575 - Precision: 0.8776 - Recall: 0.8856 - accuracy: 0.8807 - loss: 0.2887
# Epoch 15: val_loss did not improve from 0.54190
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9575 - Precision: 0.8779 - Recall: 0.8861 - accuracy: 0.8811 - loss: 0.2884 - val_AUC: 0.7134 - val_Precision: 0.2471 - val_Recall: 0.4831 - val_accuracy: 0.7234 - val_loss: 0.7010
# Epoch 16/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9620 - Precision: 0.8865 - Recall: 0.9142 - accuracy: 0.8983 - loss: 0.2726
# Epoch 16: val_loss did not improve from 0.54190
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9622 - Precision: 0.8869 - Recall: 0.9138 - accuracy: 0.8984 - loss: 0.2722 - val_AUC: 0.7197 - val_Precision: 0.2774 - val_Recall: 0.4270 - val_accuracy: 0.7656 - val_loss: 0.6249
# Epoch 17/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9630 - Precision: 0.8921 - Recall: 0.9042 - accuracy: 0.8972 - loss: 0.2708
# Epoch 17: val_loss did not improve from 0.54190
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9631 - Precision: 0.8923 - Recall: 0.9044 - accuracy: 0.8975 - loss: 0.2705 - val_AUC: 0.7122 - val_Precision: 0.2672 - val_Recall: 0.3483 - val_accuracy: 0.7766 - val_loss: 0.6141
# Epoch 18/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9696 - Precision: 0.9044 - Recall: 0.9148 - accuracy: 0.9087 - loss: 0.2494
# Epoch 18: val_loss did not improve from 0.54190
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9696 - Precision: 0.9043 - Recall: 0.9150 - accuracy: 0.9088 - loss: 0.2492 - val_AUC: 0.7035 - val_Precision: 0.2658 - val_Recall: 0.4719 - val_accuracy: 0.7453 - val_loss: 0.7159
# Epoch 19/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9682 - Precision: 0.8943 - Recall: 0.9269 - accuracy: 0.9085 - loss: 0.2549
# Epoch 19: val_loss did not improve from 0.54190
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9683 - Precision: 0.8946 - Recall: 0.9266 - accuracy: 0.9085 - loss: 0.2548 - val_AUC: 0.7299 - val_Precision: 0.2770 - val_Recall: 0.4607 - val_accuracy: 0.7578 - val_loss: 0.6315
# Model training finished.
# Model training completed.
# Evaluating model on test data...
# Evaluating model...
# Model evaluation finished.
# Model evaluation completed.
# Generating predictions...
# Prediction generation finished.
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
# No Mortality       0.90      0.83      0.86       689
#    Mortality       0.29      0.44      0.35       111
#
#     accuracy                           0.77       800
#    macro avg       0.60      0.63      0.61       800
# weighted avg       0.82      0.77      0.79       800
#
#
# --- Running experiment for /content/sample_data/cnn_lstm_12hour_data.npz ---
# Data loaded from: /content/sample_data/cnn_lstm_12hour_data.npz
# X_train shape: (4406, 12, 28), static_train shape: (4406, 7), y_train shape: (4406,)
# Time series input shape: (12, 28), Static input shape: (7,)
# CNN_LSTM_Model instantiated.
# Model compiled successfully.
# Starting model training for 50 epochs with batch size 32...
# Training model...
# Epoch 1/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.6364 - Precision: 0.6055 - Recall: 0.5582 - accuracy: 0.5977 - loss: 0.6839
# Epoch 1: val_loss improved from inf to 0.63748, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - AUC: 0.6404 - Precision: 0.6081 - Recall: 0.5628 - accuracy: 0.6007 - loss: 0.6818 - val_AUC: 0.7313 - val_Precision: 0.2461 - val_Recall: 0.7079 - val_accuracy: 0.6578 - val_loss: 0.6375
# Epoch 2/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.7950 - Precision: 0.7109 - Recall: 0.7976 - accuracy: 0.7361 - loss: 0.5715
# Epoch 2: val_loss improved from 0.63748 to 0.58343, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.7960 - Precision: 0.7115 - Recall: 0.7982 - accuracy: 0.7368 - loss: 0.5703 - val_AUC: 0.7389 - val_Precision: 0.2490 - val_Recall: 0.6742 - val_accuracy: 0.6719 - val_loss: 0.5834
# Epoch 3/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8435 - Precision: 0.7479 - Recall: 0.8538 - accuracy: 0.7825 - loss: 0.5059
# Epoch 3: val_loss did not improve from 0.58343
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8441 - Precision: 0.7484 - Recall: 0.8536 - accuracy: 0.7829 - loss: 0.5050 - val_AUC: 0.7265 - val_Precision: 0.2532 - val_Recall: 0.6742 - val_accuracy: 0.6781 - val_loss: 0.5869
# Epoch 4/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8834 - Precision: 0.7789 - Recall: 0.8777 - accuracy: 0.8137 - loss: 0.4481
# Epoch 4: val_loss improved from 0.58343 to 0.57269, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8834 - Precision: 0.7790 - Recall: 0.8776 - accuracy: 0.8137 - loss: 0.4480 - val_AUC: 0.7105 - val_Precision: 0.2537 - val_Recall: 0.5843 - val_accuracy: 0.7031 - val_loss: 0.5727
# Epoch 5/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8991 - Precision: 0.7994 - Recall: 0.8783 - accuracy: 0.8286 - loss: 0.4189
# Epoch 5: val_loss improved from 0.57269 to 0.54603, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.8992 - Precision: 0.7994 - Recall: 0.8783 - accuracy: 0.8286 - loss: 0.4188 - val_AUC: 0.7104 - val_Precision: 0.2606 - val_Recall: 0.5506 - val_accuracy: 0.7203 - val_loss: 0.5460
# Epoch 6/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9175 - Precision: 0.8241 - Recall: 0.8794 - accuracy: 0.8456 - loss: 0.3856
# Epoch 6: val_loss did not improve from 0.54603
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9177 - Precision: 0.8243 - Recall: 0.8791 - accuracy: 0.8456 - loss: 0.3853 - val_AUC: 0.6975 - val_Precision: 0.2662 - val_Recall: 0.4607 - val_accuracy: 0.7484 - val_loss: 0.5607
# Epoch 7/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9326 - Precision: 0.8553 - Recall: 0.8875 - accuracy: 0.8684 - loss: 0.3507
# Epoch 7: val_loss did not improve from 0.54603
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9326 - Precision: 0.8553 - Recall: 0.8874 - accuracy: 0.8684 - loss: 0.3507 - val_AUC: 0.6747 - val_Precision: 0.2381 - val_Recall: 0.3933 - val_accuracy: 0.7406 - val_loss: 0.6012
# Epoch 8/50
# 135/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9421 - Precision: 0.8578 - Recall: 0.8981 - accuracy: 0.8743 - loss: 0.3268
# Epoch 8: val_loss did not improve from 0.54603
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9421 - Precision: 0.8580 - Recall: 0.8979 - accuracy: 0.8744 - loss: 0.3268 - val_AUC: 0.6850 - val_Precision: 0.2674 - val_Recall: 0.5169 - val_accuracy: 0.7359 - val_loss: 0.6239
# Epoch 9/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9483 - Precision: 0.8653 - Recall: 0.8959 - accuracy: 0.8779 - loss: 0.3137
# Epoch 9: val_loss did not improve from 0.54603
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9484 - Precision: 0.8657 - Recall: 0.8957 - accuracy: 0.8780 - loss: 0.3134 - val_AUC: 0.6886 - val_Precision: 0.2636 - val_Recall: 0.3820 - val_accuracy: 0.7656 - val_loss: 0.5973
# Epoch 10/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9484 - Precision: 0.8585 - Recall: 0.8931 - accuracy: 0.8725 - loss: 0.3122
# Epoch 10: val_loss did not improve from 0.54603
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9485 - Precision: 0.8586 - Recall: 0.8931 - accuracy: 0.8726 - loss: 0.3121 - val_AUC: 0.6902 - val_Precision: 0.2520 - val_Recall: 0.3483 - val_accuracy: 0.7656 - val_loss: 0.6146
# Epoch 11/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9570 - Precision: 0.8800 - Recall: 0.9024 - accuracy: 0.8894 - loss: 0.2882
# Epoch 11: val_loss did not improve from 0.54603
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9571 - Precision: 0.8804 - Recall: 0.9024 - accuracy: 0.8897 - loss: 0.2880 - val_AUC: 0.6881 - val_Precision: 0.2721 - val_Recall: 0.4157 - val_accuracy: 0.7641 - val_loss: 0.6325
# Epoch 12/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9642 - Precision: 0.8926 - Recall: 0.9207 - accuracy: 0.9048 - loss: 0.2655
# Epoch 12: val_loss did not improve from 0.54603
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9642 - Precision: 0.8928 - Recall: 0.9204 - accuracy: 0.9048 - loss: 0.2654 - val_AUC: 0.6798 - val_Precision: 0.2611 - val_Recall: 0.4607 - val_accuracy: 0.7437 - val_loss: 0.7178
# Epoch 13/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9644 - Precision: 0.8929 - Recall: 0.9176 - accuracy: 0.9036 - loss: 0.2677
# Epoch 13: val_loss did not improve from 0.54603
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9644 - Precision: 0.8930 - Recall: 0.9176 - accuracy: 0.9036 - loss: 0.2676 - val_AUC: 0.6926 - val_Precision: 0.2692 - val_Recall: 0.4719 - val_accuracy: 0.7484 - val_loss: 0.7167
# Epoch 14/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9684 - Precision: 0.8934 - Recall: 0.9197 - accuracy: 0.9045 - loss: 0.2521
# Epoch 14: val_loss did not improve from 0.54603
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.9686 - Precision: 0.8941 - Recall: 0.9196 - accuracy: 0.9049 - loss: 0.2516 - val_AUC: 0.6820 - val_Precision: 0.2844 - val_Recall: 0.3483 - val_accuracy: 0.7875 - val_loss: 0.6906
# Epoch 15/50
# 136/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9715 - Precision: 0.9094 - Recall: 0.9248 - accuracy: 0.9161 - loss: 0.2413
# Epoch 15: val_loss did not improve from 0.54603
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9716 - Precision: 0.9094 - Recall: 0.9248 - accuracy: 0.9161 - loss: 0.2412 - val_AUC: 0.6544 - val_Precision: 0.2661 - val_Recall: 0.3708 - val_accuracy: 0.7703 - val_loss: 0.7377
# Model training finished.
# Model training completed.
# Evaluating model on test data...
# Evaluating model...
# Model evaluation finished.
# Model evaluation completed.
# Generating predictions...
# Prediction generation finished.
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
# No Mortality       0.92      0.74      0.82       689
#    Mortality       0.27      0.59      0.37       111
#
#     accuracy                           0.72       800
#    macro avg       0.60      0.67      0.60       800
# weighted avg       0.83      0.72      0.76       800
#
#
# --- Running experiment for /content/sample_data/cnn_lstm_36hour_data.npz ---
# Data loaded from: /content/sample_data/cnn_lstm_36hour_data.npz
# X_train shape: (4406, 36, 28), static_train shape: (4406, 7), y_train shape: (4406,)
# Time series input shape: (36, 28), Static input shape: (7,)
# CNN_LSTM_Model instantiated.
# Model compiled successfully.
# Starting model training for 50 epochs with batch size 32...
# Training model...
# Epoch 1/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.6958 - Precision: 0.6482 - Recall: 0.6381 - accuracy: 0.6461 - loss: 0.6507
# Epoch 1: val_loss improved from inf to 0.61510, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - AUC: 0.6992 - Precision: 0.6504 - Recall: 0.6418 - accuracy: 0.6487 - loss: 0.6483 - val_AUC: 0.7517 - val_Precision: 0.2583 - val_Recall: 0.6966 - val_accuracy: 0.6797 - val_loss: 0.6151
# Epoch 2/50
# 137/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8305 - Precision: 0.7256 - Recall: 0.8181 - accuracy: 0.7539 - loss: 0.5229
# Epoch 2: val_loss improved from 0.61510 to 0.56696, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.8308 - Precision: 0.7259 - Recall: 0.8183 - accuracy: 0.7542 - loss: 0.5225 - val_AUC: 0.7620 - val_Precision: 0.2802 - val_Recall: 0.6517 - val_accuracy: 0.7188 - val_loss: 0.5670
# Epoch 3/50
# 137/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8736 - Precision: 0.7710 - Recall: 0.8445 - accuracy: 0.7967 - loss: 0.4636
# Epoch 3: val_loss did not improve from 0.56696
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8738 - Precision: 0.7711 - Recall: 0.8447 - accuracy: 0.7968 - loss: 0.4633 - val_AUC: 0.7697 - val_Precision: 0.2796 - val_Recall: 0.6629 - val_accuracy: 0.7156 - val_loss: 0.5937
# Epoch 4/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.8993 - Precision: 0.7971 - Recall: 0.8699 - accuracy: 0.8238 - loss: 0.4217
# Epoch 4: val_loss did not improve from 0.56696
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.8994 - Precision: 0.7972 - Recall: 0.8700 - accuracy: 0.8239 - loss: 0.4215 - val_AUC: 0.7731 - val_Precision: 0.2957 - val_Recall: 0.6180 - val_accuracy: 0.7422 - val_loss: 0.5785
# Epoch 5/50
# 137/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9265 - Precision: 0.8265 - Recall: 0.8801 - accuracy: 0.8472 - loss: 0.3677
# Epoch 5: val_loss improved from 0.56696 to 0.51349, saving model to best_model.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - AUC: 0.9266 - Precision: 0.8266 - Recall: 0.8801 - accuracy: 0.8472 - loss: 0.3676 - val_AUC: 0.7828 - val_Precision: 0.3467 - val_Recall: 0.5843 - val_accuracy: 0.7891 - val_loss: 0.5135
# Epoch 6/50
# 137/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9400 - Precision: 0.8526 - Recall: 0.8810 - accuracy: 0.8641 - loss: 0.3335
# Epoch 6: val_loss did not improve from 0.51349
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9400 - Precision: 0.8526 - Recall: 0.8810 - accuracy: 0.8641 - loss: 0.3334 - val_AUC: 0.7659 - val_Precision: 0.2994 - val_Recall: 0.5618 - val_accuracy: 0.7563 - val_loss: 0.5616
# Epoch 7/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9462 - Precision: 0.8575 - Recall: 0.8870 - accuracy: 0.8697 - loss: 0.3196
# Epoch 7: val_loss did not improve from 0.51349
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.9463 - Precision: 0.8578 - Recall: 0.8872 - accuracy: 0.8699 - loss: 0.3191 - val_AUC: 0.7605 - val_Precision: 0.3176 - val_Recall: 0.5281 - val_accuracy: 0.7766 - val_loss: 0.5493
# Epoch 8/50
# 136/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9536 - Precision: 0.8632 - Recall: 0.9008 - accuracy: 0.8789 - loss: 0.2995
# Epoch 8: val_loss did not improve from 0.51349
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.9537 - Precision: 0.8634 - Recall: 0.9009 - accuracy: 0.8791 - loss: 0.2993 - val_AUC: 0.7381 - val_Precision: 0.3117 - val_Recall: 0.5393 - val_accuracy: 0.7703 - val_loss: 0.6303
# Epoch 9/50
# 136/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9565 - Precision: 0.8765 - Recall: 0.8950 - accuracy: 0.8844 - loss: 0.2901
# Epoch 9: val_loss did not improve from 0.51349
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.9566 - Precision: 0.8768 - Recall: 0.8953 - accuracy: 0.8846 - loss: 0.2898 - val_AUC: 0.7382 - val_Precision: 0.2751 - val_Recall: 0.5843 - val_accuracy: 0.7281 - val_loss: 0.7529
# Epoch 10/50
# 137/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9592 - Precision: 0.8757 - Recall: 0.9181 - accuracy: 0.8937 - loss: 0.2855
# Epoch 10: val_loss did not improve from 0.51349
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - AUC: 0.9592 - Precision: 0.8759 - Recall: 0.9182 - accuracy: 0.8938 - loss: 0.2852 - val_AUC: 0.7360 - val_Precision: 0.3237 - val_Recall: 0.5056 - val_accuracy: 0.7844 - val_loss: 0.6012
# Epoch 11/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9665 - Precision: 0.8932 - Recall: 0.9189 - accuracy: 0.9044 - loss: 0.2600
# Epoch 11: val_loss did not improve from 0.51349
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9666 - Precision: 0.8935 - Recall: 0.9191 - accuracy: 0.9046 - loss: 0.2596 - val_AUC: 0.7289 - val_Precision: 0.3459 - val_Recall: 0.5169 - val_accuracy: 0.7969 - val_loss: 0.6608
# Epoch 12/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9689 - Precision: 0.8935 - Recall: 0.9207 - accuracy: 0.9053 - loss: 0.2497
# Epoch 12: val_loss did not improve from 0.51349
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.9689 - Precision: 0.8935 - Recall: 0.9207 - accuracy: 0.9053 - loss: 0.2497 - val_AUC: 0.7333 - val_Precision: 0.3117 - val_Recall: 0.5393 - val_accuracy: 0.7703 - val_loss: 0.7428
# Epoch 13/50
# 137/138 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - AUC: 0.9738 - Precision: 0.9057 - Recall: 0.9240 - accuracy: 0.9138 - loss: 0.2340
# Epoch 13: val_loss did not improve from 0.51349
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - AUC: 0.9739 - Precision: 0.9059 - Recall: 0.9241 - accuracy: 0.9139 - loss: 0.2338 - val_AUC: 0.7188 - val_Precision: 0.2550 - val_Recall: 0.4270 - val_accuracy: 0.7469 - val_loss: 0.7005
# Epoch 14/50
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9734 - Precision: 0.9054 - Recall: 0.9280 - accuracy: 0.9154 - loss: 0.2354
# Epoch 14: val_loss did not improve from 0.51349
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9734 - Precision: 0.9055 - Recall: 0.9280 - accuracy: 0.9155 - loss: 0.2352 - val_AUC: 0.7025 - val_Precision: 0.2810 - val_Recall: 0.4831 - val_accuracy: 0.7563 - val_loss: 0.8055
# Epoch 15/50
# 133/138 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - AUC: 0.9749 - Precision: 0.9030 - Recall: 0.9297 - accuracy: 0.9147 - loss: 0.2280
# Epoch 15: val_loss did not improve from 0.51349
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - AUC: 0.9751 - Precision: 0.9036 - Recall: 0.9299 - accuracy: 0.9152 - loss: 0.2274 - val_AUC: 0.7340 - val_Precision: 0.3261 - val_Recall: 0.5056 - val_accuracy: 0.7859 - val_loss: 0.7140
# Model training finished.
# Model training completed.
# Evaluating model on test data...
# Evaluating model...
# Model evaluation finished.
# Model evaluation completed.
# Generating predictions...
# Prediction generation finished.
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
# No Mortality       0.93      0.80      0.86       689
#    Mortality       0.33      0.60      0.43       111
#
#     accuracy                           0.78       800
#    macro avg       0.63      0.70      0.64       800
# weighted avg       0.84      0.78      0.80       800
#
#
# --- All experiments finished ---

# %%
# Create a pandas DataFrame from the results
results_df = pd.DataFrame(all_results)

# Reorder columns for better readability
results_df = results_df[['dataset', 'loss', 'accuracy', 'auc', 'precision', 'recall']]

# Display the table
print("\n--- Experiment Results Summary ---")
display(results_df)
# Out:
# --- Experiment Results Summary ---
#                                          dataset      loss  accuracy  \
# 0  /content/sample_data/cnn_lstm_48hour_data.npz  0.442445   0.82625
# 1   /content/sample_data/cnn_lstm_6hour_data.npz  0.533155   0.77375
# 2  /content/sample_data/cnn_lstm_12hour_data.npz  0.542132   0.72375
# 3  /content/sample_data/cnn_lstm_36hour_data.npz  0.465912   0.77500
#
#         auc  precision    recall
# 0  0.797657   0.375000  0.378378
# 1  0.718315   0.291667  0.441441
# 2  0.731600   0.272727  0.594595
# 3  0.817832   0.330049  0.603604

# %% [markdown]
# ### 6. Results Summary Table
#
#  The results obtained from training and evaluating the CNN-LSTM model on time windows Compare the performance metrics (loss, accuracy, AUC, precision, and recall) to understand the impact of using time series data of different lengths (6, 12, 36, and 48 hours) on the model's ability to predict ICU mortality.
#
# **Experiment Results Summary:**
#
# | Time Window                                      | loss     | accuracy | auc      | precision | recall   |
# |------------------------------------------------- |----------|----------|----------|-----------|----------|
# | 48hr                       | 0.421448 | 0.83875  | 0.819885 | 0.404255  | 0.342342 |
# | 6hr                        | 0.528127 | 0.74375  | 0.741328 | 0.282407  | 0.549550 |
# | 12hr                       | 0.538580 | 0.73875  | 0.752736 | 0.285088  | 0.585586 |
# | 36hr                       | 0.485300 | 0.79125  | 0.824743 | 0.354167  | 0.612613 |
#
# Based on the analysis of the evaluation metrics, the **`36hr`** time window appears to be the most promising for this ICU mortality prediction task. While the 48-hour dataset shows the highest accuracy and precision, the 36-hour dataset achieves a strong balance with the highest Recall (0.612613) and the highest AUC (0.824743). In a medical context, maximizing Recall is often crucial to ensure that as many true positive cases (patients who will unfortunately experience mortality) are identified as possible, even if it means a slight trade-off in precision. The high AUC for the 36-hour dataset also indicates good overall discriminative performance.

# %% [markdown]
# ### 7. Cross-Validation on  Dataset
#
# **Why Cross-Validation?**
#
# Cross-validation is a robust statistical method used to assess the generalizability and reliability of machine learning models. In this notebook, stratified k-fold cross-validation is applied to the best-performing 36-hour dataset to ensure that the CNN-LSTM model's performance metrics (accuracy, AUC, precision, recall, loss) are not biased by a single train-test split.
#
# **Key Reasons for Cross-Validation:**
# - **Generalization:** It helps estimate how well the model will perform on unseen data, reducing the risk of overfitting.
# - **Robustness:** By averaging results across multiple folds, we obtain more stable and reliable performance metrics.
# - **Class Balance:** Stratified k-fold ensures each fold maintains the same proportion of mortality cases, which is crucial for medical datasets with class imbalance.
#
# **Process:**
# - The combined training and validation data are split into k folds (here, k=5).
# - For each fold, the model is trained on k-1 folds and validated on the remaining fold.
# - Performance metrics are recorded for each fold and then averaged to provide a comprehensive evaluation.
#
# This approach provides a more trustworthy estimate of the model's true predictive power and helps guide model selection and hyperparameter tuning.

# %%
# Load the 36-hour dataset
data_path_36hour = '../data/processed/cnn_lstm_36hour_data.npz'
X_train_36, X_val_36, X_test_36, static_train_36, static_val_36, static_test_36, y_train_36, y_val_36, y_test_36 = load_icu_data(data_path_36hour)

# Reshape y arrays to be 1D for StratifiedKFold split
y_train_36_reshaped = y_train_36.flatten()
y_val_36_reshaped = y_val_36.flatten()


# Combine training and validation data for cross-validation
X_combined_36 = np.vstack((X_train_36, X_val_36))
static_combined_36 = np.vstack((static_train_36, static_val_36))
y_combined_36 = np.hstack((y_train_36_reshaped, y_val_36_reshaped))


# Verify the shapes
print("Shape of combined time-series data (36-hour):", X_combined_36.shape)
print("Shape of combined static data (36-hour):", static_combined_36.shape)
print("Shape of combined target variable (36-hour):", y_combined_36.shape)

# Determine input shapes for the model from the combined data
time_series_input_shape_36 = (X_combined_36.shape[1], X_combined_36.shape[2])
static_input_shape_36 = (static_combined_36.shape[1],)
print(f"Time series input shape (36-hour): {time_series_input_shape_36}, Static input shape (36-hour): {static_input_shape_36}")
# Out:
# Shape of combined time-series data (36-hour): (5046, 36, 28)
# Shape of combined static data (36-hour): (5046, 7)
# Shape of combined target variable (36-hour): (5046,)
# Time series input shape (36-hour): (36, 28), Static input shape (36-hour): (7,)

# %%
# Define the number of splits for k-fold cross-validation
n_splits = 5
print(f"Number of splits for k-fold cross-validation: {n_splits}")

# Instantiate StratifiedKFold
kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# Initialize empty lists to store the evaluation metrics for each fold
fold_loss_36 = []
fold_accuracy_36 = []
fold_auc_36 = []
fold_precision_36 = []
fold_recall_36 = []

#  Start a loop that iterates through the splits
for fold, (train_index, val_index) in enumerate(kf.split(X_combined_36, y_combined_36)):
    #  Print the current fold number
    print(f"\n--- Starting Fold {fold + 1}/{n_splits} on 36-hour data ---")

    # Split data into training and validation sets for the current fold
    X_train_fold, X_val_fold = X_combined_36[train_index], X_combined_36[val_index]
    static_train_fold, static_val_fold = static_combined_36[train_index], static_combined_36[val_index]
    y_train_fold, y_val_fold = y_combined_36[train_index], y_combined_36[val_index]

    # Build a fresh model for the current fold
    model = build_cnn_lstm_model(time_series_input_shape_36, static_input_shape_36)

    # Compile the model inside the loop with the correct metrics
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss='binary_crossentropy',
        metrics=[
            'accuracy',
            tf.keras.metrics.AUC(name='AUC'),
            tf.keras.metrics.Precision(name='Precision'),
            tf.keras.metrics.Recall(name='Recall')
        ]
    )

    # Define callbacks for the current fold
    fold_early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )

    # Train the model on the training data for the current fold
    print("Training model for current fold...")
    history_fold = model.fit(
        x=[X_train_fold, static_train_fold],
        y=y_train_fold,
        epochs=100, # Use a sufficiently large number of epochs, EarlyStopping will manage the actual number
        batch_size=32,
        validation_data=([X_val_fold, static_val_fold], y_val_fold),
        callbacks=[fold_early_stopping],
        verbose=0 # Set to 1 to see training progress per epoch
    )
    print("Training finished for current fold.")

    # Evaluate the model on the validation data for the current fold
    print("Evaluating model for current fold...")
    loss, accuracy, auc, precision, recall = model.evaluate(
        x=[X_val_fold, static_val_fold],
        y=y_val_fold,
        verbose=0
    )
    print(f"Fold {fold + 1} - Loss: {loss:.4f}, Accuracy: {accuracy:.4f}, AUC: {auc:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}")

    # Store the metrics
    fold_loss_36.append(loss)
    fold_accuracy_36.append(accuracy)
    fold_auc_36.append(auc)
    fold_precision_36.append(precision)
    fold_recall_36.append(recall)


print("\n--- Cross-validation finished on 36-hour data ---")
# Out:
# Number of splits for k-fold cross-validation: 5
#
# --- Starting Fold 1/5 on 36-hour data ---
# Training model for current fold...
# Training finished for current fold.
# Evaluating model for current fold...
# Fold 1 - Loss: 0.3587, Accuracy: 0.8762, AUC: 0.9435, Precision: 0.8236, Recall: 0.9259
#
# --- Starting Fold 2/5 on 36-hour data ---
# Training model for current fold...
# Training finished for current fold.
# Evaluating model for current fold...
# Fold 2 - Loss: 0.3428, Accuracy: 0.8791, AUC: 0.9446, Precision: 0.8636, Recall: 0.8712
#
# --- Starting Fold 3/5 on 36-hour data ---
# Training model for current fold...
# Training finished for current fold.
# Evaluating model for current fold...
# Fold 3 - Loss: 0.3110, Accuracy: 0.8890, AUC: 0.9545, Precision: 0.8914, Recall: 0.8603
#
# --- Starting Fold 4/5 on 36-hour data ---
# Training model for current fold...
# Training finished for current fold.
# Evaluating model for current fold...
# Fold 4 - Loss: 0.2994, Accuracy: 0.8811, AUC: 0.9605, Precision: 0.9005, Recall: 0.8297
#
# --- Starting Fold 5/5 on 36-hour data ---
# Training model for current fold...
# Training finished for current fold.
# Evaluating model for current fold...
# Fold 5 - Loss: 0.3417, Accuracy: 0.8682, AUC: 0.9412, Precision: 0.8368, Recall: 0.8824
#
# --- Cross-validation finished on 36-hour data ---

# %%
# Determine input shapes for the final model based on the combined 36-hour data
time_series_input_shape_final = (X_combined_36.shape[1], X_combined_36.shape[2])
static_input_shape_final = (static_combined_36.shape[1],)

final_model = build_cnn_lstm_model(time_series_input_shape_final, static_input_shape_final)

# Compile the final model
final_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        tf.keras.metrics.AUC(name='AUC'),
        tf.keras.metrics.Precision(name='Precision'),
        tf.keras.metrics.Recall(name='Recall')
    ]
)


# Define Early Stopping callback for the final training
final_early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

print("Training final model on combined training and validation data (36-hour dataset)...")

epochs_for_final_training = 25


history_final = final_model.fit(
    x=[X_combined_36, static_combined_36],
    y=y_combined_36,
    epochs=epochs_for_final_training,
    batch_size=32,
    verbose=1
)

print("Final model training finished.")

# Save the final model
model_save_path_final = '../models/base_model_36hour.keras'
final_model.save(model_save_path_final)
print(f"Final model saved to: {model_save_path_final}")
# Out:
# Training final model on combined training and validation data (36-hour dataset)...
# Epoch 1/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - AUC: 0.6912 - Precision: 0.6270 - Recall: 0.5017 - accuracy: 0.6470 - loss: 0.6471
# Epoch 2/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8397 - Precision: 0.7386 - Recall: 0.7687 - accuracy: 0.7734 - loss: 0.5167
# Epoch 3/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.8711 - Precision: 0.7566 - Recall: 0.8092 - accuracy: 0.7969 - loss: 0.4688
# Epoch 4/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - AUC: 0.8923 - Precision: 0.7658 - Recall: 0.8348 - accuracy: 0.8107 - loss: 0.4340
# Epoch 5/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - AUC: 0.9111 - Precision: 0.7966 - Recall: 0.8405 - accuracy: 0.8314 - loss: 0.3995
# Epoch 6/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9271 - Precision: 0.8219 - Recall: 0.8515 - accuracy: 0.8500 - loss: 0.3667
# Epoch 7/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9377 - Precision: 0.8428 - Recall: 0.8477 - accuracy: 0.8603 - loss: 0.3415
# Epoch 8/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9452 - Precision: 0.8471 - Recall: 0.8745 - accuracy: 0.8724 - loss: 0.3217
# Epoch 9/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9501 - Precision: 0.8607 - Recall: 0.8807 - accuracy: 0.8819 - loss: 0.3111
# Epoch 10/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - AUC: 0.9580 - Precision: 0.8818 - Recall: 0.8861 - accuracy: 0.8952 - loss: 0.2882
# Epoch 11/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9589 - Precision: 0.8830 - Recall: 0.8757 - accuracy: 0.8919 - loss: 0.2851
# Epoch 12/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - AUC: 0.9641 - Precision: 0.8827 - Recall: 0.9112 - accuracy: 0.9053 - loss: 0.2681
# Epoch 13/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9692 - Precision: 0.8896 - Recall: 0.9008 - accuracy: 0.9051 - loss: 0.2520
# Epoch 14/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9709 - Precision: 0.8990 - Recall: 0.9080 - accuracy: 0.9128 - loss: 0.2452
# Epoch 15/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9702 - Precision: 0.8986 - Recall: 0.8963 - accuracy: 0.9080 - loss: 0.2487
# Epoch 16/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9782 - Precision: 0.9151 - Recall: 0.9165 - accuracy: 0.9240 - loss: 0.2182
# Epoch 17/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9765 - Precision: 0.9112 - Recall: 0.9167 - accuracy: 0.9222 - loss: 0.2245
# Epoch 18/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - AUC: 0.9791 - Precision: 0.9177 - Recall: 0.9154 - accuracy: 0.9251 - loss: 0.2138
# Epoch 19/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - AUC: 0.9788 - Precision: 0.9201 - Recall: 0.9094 - accuracy: 0.9238 - loss: 0.2181
# Epoch 20/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - AUC: 0.9811 - Precision: 0.9199 - Recall: 0.9155 - accuracy: 0.9260 - loss: 0.2061
# Epoch 21/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9820 - Precision: 0.9284 - Recall: 0.9252 - accuracy: 0.9340 - loss: 0.2025
# Epoch 22/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9854 - Precision: 0.9379 - Recall: 0.9229 - accuracy: 0.9378 - loss: 0.1879
# Epoch 23/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9835 - Precision: 0.9372 - Recall: 0.9270 - accuracy: 0.9392 - loss: 0.1956
# Epoch 24/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - AUC: 0.9833 - Precision: 0.9310 - Recall: 0.9192 - accuracy: 0.9332 - loss: 0.2003
# Epoch 25/25
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - AUC: 0.9867 - Precision: 0.9509 - Recall: 0.9280 - accuracy: 0.9460 - loss: 0.1808
# Final model training finished.
# Final model saved to: base_model_36hour.keras

# %%
# Evaluate the final model on the test set of the 36-hour data
loss_final, accuracy_final, auc_final, precision_final, recall_final = final_model.evaluate(
    x=[X_test_36, static_test_36],
    y=y_test_36,
    verbose=0
)

print("--- Final Model Evaluation on Test Data (36-hour dataset) ---")
print(f"Test Loss: {loss_final:.4f}")
print(f"Test Accuracy: {accuracy_final:.4f}")
print(f"Test AUC: {auc_final:.4f}")
print(f"Test Precision: {precision_final:.4f}")
print(f"Test Recall: {recall_final:.4f}")
# Out:
# --- Final Model Evaluation on Test Data (36-hour dataset) ---
# Test Loss: 0.7402
# Test Accuracy: 0.7850
# Test AUC: 0.7563
# Test Precision: 0.3129
# Test Recall: 0.4595

# %%
# Aggregate and present the cross-validation results for the 36-hour dataset
print("\n--- Cross-validation Results (36-hour dataset) ---")
print(f"Average Loss: {np.mean(fold_loss_36):.4f} +/- {np.std(fold_loss_36):.4f}")
print(f"Average Accuracy: {np.mean(fold_accuracy_36):.4f} +/- {np.std(fold_accuracy_36):.4f}")
print(f"Average AUC: {np.mean(fold_auc_36):.4f} +/- {np.std(fold_auc_36):.4f}")
print(f"Average Precision: {np.mean(fold_precision_36):.4f} +/- {np.std(fold_precision_36):.4f}")
print(f"Average Recall: {np.mean(fold_recall_36):.4f} +/- {np.std(fold_recall_36):.4f}")
# Out:
# --- Cross-validation Results (36-hour dataset) ---
# Average Loss: 0.3307 +/- 0.0220
# Average Accuracy: 0.8787 +/- 0.0068
# Average AUC: 0.9488 +/- 0.0074
# Average Precision: 0.8632 +/- 0.0298
# Average Recall: 0.8739 +/- 0.0314

# %% [markdown]
# ### 8. Hyperparameter Tuning
#
# Hyperparameter tuning is a critical step in deep learning model development. It involves systematically searching for the best combination of model parameters (such as number of layers, units, dropout rates, and learning rate) to maximize predictive performance.
#
#
# **Why Tune Hyperparameters?**
#
# - Deep learning models have many settings that can dramatically affect their accuracy, generalization, and robustness.
# - Manual selection is often suboptimal and time-consuming; automated tuning finds better configurations efficiently.
#
#
# **How is Tuning Performed Here?**
#
# - We use KerasTuner's Hyperband algorithm, which efficiently explores the hyperparameter space using adaptive resource allocation and early stopping.
# - The tuner searches for the best model based on validation recall, which is crucial for medical tasks where identifying true positives is important.
# - The process includes varying the number of filters, LSTM units, dense layer sizes, dropout rates, and learning rate.
#
#
# **Impact:**
#
# - Well-tuned models are more accurate, less prone to overfitting, and better suited for deployment in real-world clinical settings.
# - The best hyperparameters found are used to build and evaluate the final enhanced model.

# %%
def build_tunable_cnn_lstm_model(hp: HyperParameters):
    """Builds a CNN-LSTM model with tunable hyperparameters."""

    # Time-series branch
    time_series_input = Input(shape=time_series_input_shape_final, name='time_series_input')

    # Tunable Conv1D layers
    filters_conv1d_1 = hp.Int('filters_conv1d_1', min_value=32, max_value=128, step=32)
    x = Conv1D(filters_conv1d_1, 3, activation='relu', padding='same', kernel_regularizer=l2(1e-4))(time_series_input)
    x = MaxPooling1D(pool_size=2)(x)
    x = Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1))(x)

    filters_conv1d_2 = hp.Int('filters_conv1d_2', min_value=64, max_value=256, step=32)
    x = Conv1D(filters_conv1d_2, 3, activation='relu', padding='same', kernel_regularizer=l2(1e-4))(x)
    x = MaxPooling1D(pool_size=1)(x)  # Keep pool_size=1 for short sequences
    x = Dropout(hp.Float('dropout_2', min_value=0.1, max_value=0.5, step=0.1))(x)

    # Tunable LSTM layer
    lstm_units = hp.Int('lstm_units', min_value=32, max_value=128, step=32)
    x = LSTM(lstm_units, return_sequences=False, kernel_regularizer=l2(1e-4))(x)
    x = Dropout(hp.Float('dropout_3', min_value=0.1, max_value=0.5, step=0.1))(x)

    # Static branch
    static_input = Input(shape=static_input_shape_final, name='static_input')

    # Tunable Dense layers for static branch
    dense_units_static_1 = hp.Int('dense_units_static_1', min_value=16, max_value=64, step=16)
    y = Dense(dense_units_static_1, activation='relu')(static_input)
    dense_units_static_2 = hp.Int('dense_units_static_2', min_value=8, max_value=32, step=8)
    y = Dense(dense_units_static_2, activation='relu')(y)

    # Merge branches
    combined = Concatenate()([x, y])

    # Tunable Dense layers after concatenation
    dense_units_combined_1 = hp.Int('dense_units_combined_1', min_value=32, max_value=128, step=32)
    z = Dense(dense_units_combined_1, activation='relu')(combined)
    z = Dropout(hp.Float('dropout_4', min_value=0.1, max_value=0.5, step=0.1))(z)

    dense_units_combined_2 = hp.Int('dense_units_combined_2', min_value=16, max_value=64, step=16)
    z = Dense(dense_units_combined_2, activation='relu')(z)

    # Output layer
    output = Dense(1, activation='sigmoid', name='output')(z)

    # Build the model
    model = Model(inputs=[time_series_input, static_input], outputs=output)

    # Compile the model with a tunable learning rate
    learning_rate = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='LOG')
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss='binary_crossentropy',
        metrics=[
            'accuracy',
            tf.keras.metrics.AUC(name='AUC'),
            tf.keras.metrics.Precision(name='Precision'),
            tf.keras.metrics.Recall(name='Recall')
        ]
    )

    return model

# %%
# Instantiate the Hyperband tuner
tuner = Hyperband(
    hypermodel=build_tunable_cnn_lstm_model,
    objective='val_Recall',
    max_epochs=50,
    factor=3,
    directory='keras_tuner_dir',
    project_name='cnn_lstm_tuning_recall',
    overwrite=True
)

print("Hyperband tuner instantiated with objective 'val_Recall'.")
# Out:
# Hyperband tuner instantiated with objective 'val_Recall'.

# %%
# Start the hyperparameter search
print("Starting hyperparameter search...")
tuner.search(
    x=[X_combined_36, static_combined_36],
    y=y_combined_36,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)]
)

print("Hyperparameter search finished.")
# Out:
# Trial 90 Complete [00h 00m 40s]
# val_Recall: 0.8649237751960754
#
# Best val_Recall So Far: 0.9586056470870972
# Total elapsed time: 00h 29m 09s
# Hyperparameter search finished.

# %% [markdown]
# ### 9. Best Model Evaluation
#
# Retrieve and evaluate the best model found by KerasTuner on the held-out test set. This step provides final performance metrics for the optimized model.

# %%
# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best Hyperparameters found:")
print(best_hps.values)

# Build the best model
enhanced_model = tuner.get_best_models(num_models=1)[0]

print("\nBest model built successfully.")
# Out:
# Best Hyperparameters found:
# {'filters_conv1d_1': 32, 'dropout_1': 0.5, 'filters_conv1d_2': 256, 'dropout_2': 0.2, 'lstm_units': 96, 'dropout_3': 0.1, 'dense_units_static_1': 32, 'dense_units_static_2': 8, 'dense_units_combined_1': 32, 'dropout_4': 0.1, 'dense_units_combined_2': 16, 'learning_rate': 0.0002832574472375902, 'tuner/epochs': 17, 'tuner/initial_epoch': 6, 'tuner/bracket': 2, 'tuner/round': 1, 'tuner/trial_id': '0065'}
#
# Best model built successfully.

# %%
# Evaluate the enhanced model on the test set
print("Evaluating the enhanced model on the test set...")
loss_enhanced, accuracy_enhanced, auc_enhanced, precision_enhanced, recall_enhanced = enhanced_model.evaluate(
    x=[X_test_36, static_test_36],  # Use the 36-hour test data
    y=y_test_36,
    verbose=0
)

print("\n--- Enhanced Model Evaluation on Test Data ---")
print(f"Test Loss: {loss_enhanced:.4f}")
print(f"Test Accuracy: {accuracy_enhanced:.4f}")
print(f"Test AUC: {auc_enhanced:.4f}")
print(f"Test Precision: {precision_enhanced:.4f}")
print(f"Test Recall: {recall_enhanced:.4f}")
# Out:
# Evaluating the enhanced model on the test set...
#
# --- Enhanced Model Evaluation on Test Data ---
# Test Loss: 0.8503
# Test Accuracy: 0.6025
# Test AUC: 0.7726
# Test Precision: 0.2353
# Test Recall: 0.8288

# %% [markdown]
# ### 10. Model Performance Comparison
#
# Compare the evaluation results of the base model and the enhanced (tuned) model. This section summarizes the trade-offs between accuracy, precision, recall, and AUC for clinical decision-making.

# %%
# Create a dictionary to store the results for comparison
comparison_results = {
    'Model': ['Base Model (36-hour)', 'Enhanced Model (Tuned)'],
    'Loss': [loss_final, loss_enhanced],
    'Accuracy': [accuracy_final, accuracy_enhanced],
    'AUC': [auc_final, auc_enhanced],
    'Precision': [precision_final, precision_enhanced],
    'Recall': [recall_final, recall_enhanced]
}

# Create a pandas DataFrame for easy comparison
comparison_df = pd.DataFrame(comparison_results)

print("\n--- Model Performance Comparison ---")
display(comparison_df)
# Out:
# --- Model Performance Comparison ---
#                     Model     Loss  Accuracy       AUC  Precision    Recall
# 0    Base Model (36-hour)  0.74020    0.7850  0.756306   0.312883  0.459459
# 1  Enhanced Model (Tuned)  0.85032    0.6025  0.772650   0.235294  0.828829

# %% [markdown]
# ### 11. Save Enhanced Model
#
# Save the enhanced CNN-LSTM model with the best hyperparameters for future inference or deployment.

# %%
# Save the enhanced model
enhanced_model_save_path = '../models/enhanced_model_36hour.keras'
enhanced_model.save(enhanced_model_save_path)
print(f"Enhanced model saved to: {enhanced_model_save_path}")
# Out:
# Enhanced model saved to: enhanced_model_36hour.keras

# %% [markdown]
# ## 12. Compare Base and Enhanced Model Performance
#
# Compare the evaluation results of the base model (trained on the 36-hour data without tuning) and the enhanced model (trained with the best hyperparameters found by KerasTuner).
#
# Based on the comparison of the Base Model and the Enhanced Model:
#
# *   **Loss:** The Base Model has a lower loss (0.74020) compared to the Enhanced Model (0.85032), suggesting slightly better fit to the training data in terms of minimizing binary cross-entropy.
#
# *   **Accuracy:** The Base Model has significantly higher accuracy (0.7850) than the Enhanced Model (0.6025), indicating better overall correct classification.
#
# *   **AUC (Area Under the ROC Curve):** The Enhanced Model has a slightly higher AUC (0.772650) compared to the Base Model (0.756306), showing a marginal improvement in discriminative power.
#
# *   **Precision:** The Base Model has higher precision (0.312883) than the Enhanced Model (0.235294), meaning it makes fewer false positive predictions.
#
# *   **Recall:** The Enhanced Model has a significantly higher recall (0.828829) compared to the Base Model (0.459459), indicating it is much better at identifying actual mortality cases (fewer false negatives).
#
# **Interpretation:**
#
# The hyperparameter tuning improved Recall significantly, which is often critical in medical prediction tasks to avoid missing true positive cases. However, this came at the cost of lower Accuracy and Precision. The Enhanced Model's slightly higher AUC suggests improved overall discrimination despite the trade-off in other metrics. The choice between the models depends on the specific clinical priorities regarding minimizing false negatives (favoring Enhanced Model) versus minimizing false positives or maximizing overall accuracy (favoring Base Model).
